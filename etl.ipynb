# %% [markdown]
# # File path /Users/pradeepsingh/Downloads/My_Demo_Sheet  - Sheet1.csv

# %%
import pandas as pd  #importing pandas lib
import numpy as np  #importing numpy lib

# %% [markdown]
# Step 1 Extract
# 📌 Architecture
# Goal: Read data from a CSV file.
# Tool: pandas.read_csv()

# %%
import pandas as pd

def extract_data(file_path):
    try:
        df = pd.read_csv(file_path)
        print("✅ Data extracted successfully.")
        return df
    except Exception as e:
        print(f"❌ Extraction failed: {e}")
        return None

# Test extraction
data = extract_data("/Users/pradeepsingh/Downloads/salesdata.csv")
if data is not None:
    print(data.head())
# Out:
# ✅ Data extracted successfully.
#   Due Renewal Month Due Renewal Month Static Due Renewal Quarter  \
# 0         02|Feb'25                02|Feb'25               Qtr-1
# 1         04|Apr'25                04|Apr'25               Qtr-2
# 2         03|Mar'25                03|Mar'25               Qtr-1
# 3         06|Jun'25                06|Jun'25               Qtr-2
# 4         08|Aug'25                08|Aug'25               Qtr-3
#
#   Customer ID(chargebee) Due Renewal Date Due renewal date(P)  \
# 0         gG89SwlyPrIqgt         7-Feb-25            7-Feb-25
# 1      AzyhPRTyX7byX3hTd        29-Apr-25           29-Apr-25
# 2      AzZnPeU5mGpz43CRq         5-Mar-25            5-Mar-25
# 3      16CV71UC6IUIT2HF2         1-Jun-25            1-Jun-25
# 4      16CV3LUMIkV123Hjd        26-Aug-25           26-Aug-25
#
#                          Organization Name  \
# 0                              ALLY Energy
# 1                                Capgemini
# 2  PMI ORGANIZATION CENTRE PRIVATE LIMITED
# 3            HMC Harborview Medical Center
# 4                       Publink Sp. z o.o.
#
#                                     Community ID  \
# 0           4589ebbe-d350-4e15-aca9-b561496049c2
# 1           90bdbb3e-cca3-46a5-8868-4259c6dc7a60
# 2   d5861ef5-6db7-4a19-a6d9-49c1a0e21c20
# 3           e63ad0ad-d4c5-4299-b25a-580c89f051a6
# 4           e9b6e7e9-6faf-4246-a499-7a69a81f0259
#
#                 Customer email id        Source  ... Churn Reasons  \
# 0            katie@allyenergy.com  Sales Assist  ...           NaN
# 1  dinesh-kumar.a.k@capgemini.com  Sales Assist  ...           NaN
# 2      registration@pmi-india.org  Sales Assist  ...           NaN
# 3    uwashington@ghxinvoicing.com  Sales Assist  ...           NaN
# 4            efaktura@publink.com  Sales Assist  ...           NaN
#
#   Custify Status update  Plan Type2(PCA) Expected closure date EG: 1-Aug-24  \
# 0                   NaN  Enterprise plan                                NaN
# 1                   NaN  Enterprise plan                                NaN
# 2                   NaN  Enterprise plan                                NaN
# 3                   NaN     Professional                                NaN
# 4                   NaN  Enterprise plan                                NaN
#
#   Expected closure Comment's Updated Forecast Account ESM  \
# 0                        NaN           333450         NaN
# 1                        NaN            45000         NaN
# 2                        NaN            44200         NaN
# 3                        NaN            27000         NaN
# 4                        NaN            44000         NaN
#
#   Renewal Probabiltiy %  \
# 0                  100%
# 1                   100
# 2                   NaN
# 3                    75
# 4                   NaN
#
#   Renewal probability of Q2 and Q3 accounts as on 9th April Unnamed: 53
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4                                                NaN                NaN
#
# [5 rows x 54 columns]

# %%
# print(data.head(10)) # first 10 rows
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 54 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Due Renewal Month                                          227 non-null    object
#  1   Due Renewal Month Static                                   227 non-null    object
#  2   Due Renewal Quarter                                        227 non-null    object
#  3   Customer ID(chargebee)                                     227 non-null    object
#  4   Due Renewal Date                                           227 non-null    object
#  5   Due renewal date(P)                                        227 non-null    object
#  6   Organization Name                                          227 non-null    object
#  7   Community ID                                               227 non-null    object
#  8   Customer email id                                          226 non-null    object
#  9   Source                                                     227 non-null    object
#  10  Duration                                                   227 non-null    object
#  11  Region Internal                                            227 non-null    object
#  12  Base Plan                                                  227 non-null    object
#  13  Domain Id                                                  227 non-null    object
#  14  L1-Revisit                                                 227 non-null    object
#  15  L2-Revisit                                                 228 non-null    object
#  16  Renewal Status                                             227 non-null    object
#  17  Renewed Amount                                             97 non-null     object
#  18  Due renewal Amount(as per Finance sheet)                   227 non-null    object
#  19  AM Name                                                    227 non-null    object
#  20  Account Manager Email_id.                                  227 non-null    object
#  21  ESM                                                        223 non-null    object
#  22  Plan Type(PCA)                                             219 non-null    object
#  23  Due renewal date(P).1                                      227 non-null    object
#  24  B2B Marketer/HR classification                             227 non-null    object
#  25  Renewal Probabiltiy                                        204 non-null    object
#  26  Finance B2B marketer Tagging                               224 non-null    object
#  27  Updated L1-Analysis                                        227 non-null    object
#  28  Updated L2-Analysis                                        227 non-null    object
#  29  ICP                                                        1 non-null      object
#  30  Grade                                                      1 non-null      object
#  31  Revenue Category                                           1 non-null      object
#  32  Renewal Bucket                                             1 non-null      object
#  33  Year Aquired                                               222 non-null    float64
#  34  Updated Forecast-                                          0 non-null      float64
#  35  85% & 45%                                                  0 non-null      float64
#  36  Validation                                                 0 non-null      float64
#  37  100% & 60%                                                 0 non-null      float64
#  38  Validation.1                                               0 non-null      float64
#  39  PPT                                                        0 non-null      float64
#  40  ACV bucket                                                 227 non-null    object
#  41  Previous CSM                                               42 non-null     object
#  42  % Renewal                                                  18 non-null     object
#  43  Unnamed: 43                                                3 non-null      object
#  44  Churn Reasons                                              7 non-null      object
#  45  Custify Status update                                      1 non-null      object
#  46  Plan Type2(PCA)                                            214 non-null    object
#  47  Expected closure date EG: 1-Aug-24                         0 non-null      float64
#  48  Expected closure Comment's                                 0 non-null      float64
#  49  Updated Forecast                                           113 non-null    object
#  50  Account ESM                                                0 non-null      float64
#  51  Renewal Probabiltiy %                                      158 non-null    object
#  52  Renewal probability of Q2 and Q3 accounts as on 9th April  0 non-null      float64
#  53  Unnamed: 53                                                112 non-null    float64
# dtypes: float64(12), object(42)
# memory usage: 114.5+ KB
# None

# %%
print(data.describe())
# Out:
#        Year Aquired  Updated Forecast-  85% & 45%  Validation  100% & 60%  \
# count    222.000000                0.0        0.0         0.0         0.0
# mean    2022.716216                NaN        NaN         NaN         NaN
# std        1.091144                NaN        NaN         NaN         NaN
# min     2020.000000                NaN        NaN         NaN         NaN
# 25%     2022.000000                NaN        NaN         NaN         NaN
# 50%     2023.000000                NaN        NaN         NaN         NaN
# 75%     2024.000000                NaN        NaN         NaN         NaN
# max     2024.000000                NaN        NaN         NaN         NaN
#
#        Validation.1  PPT  Expected closure date EG: 1-Aug-24  \
# count           0.0  0.0                                 0.0
# mean            NaN  NaN                                 NaN
# std             NaN  NaN                                 NaN
# min             NaN  NaN                                 NaN
# 25%             NaN  NaN                                 NaN
# 50%             NaN  NaN                                 NaN
# 75%             NaN  NaN                                 NaN
# max             NaN  NaN                                 NaN
#
#        Expected closure Comment's  Account ESM  \
# count                         0.0          0.0
# mean                          NaN          NaN
# std                           NaN          NaN
# min                           NaN          NaN
# 25%                           NaN          NaN
# 50%                           NaN          NaN
# 75%                           NaN          NaN
# max                           NaN          NaN
#
#        Renewal probability of Q2 and Q3 accounts as on 9th April   Unnamed: 53
# count                                                0.0            112.000000
# mean                                                 NaN           6173.754464
# std                                                  NaN           8773.916436
# min                                                  NaN              0.000000
# 25%                                                  NaN              0.000000
# 50%                                                  NaN           2450.000000
# 75%                                                  NaN           8800.000000
# max                                                  NaN          41000.000000

# %%
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 10)
print(data)
# Out:
#     Due Renewal Month Due Renewal Month Static Due Renewal Quarter  \
# 0           02|Feb'25                02|Feb'25               Qtr-1
# 1           04|Apr'25                04|Apr'25               Qtr-2
# 2           03|Mar'25                03|Mar'25               Qtr-1
# 3           06|Jun'25                06|Jun'25               Qtr-2
# 4           08|Aug'25                08|Aug'25               Qtr-3
# ..                ...                      ...                 ...
# 266               NaN                      NaN                 NaN
# 267               NaN                      NaN                 NaN
# 268               NaN                      NaN                 NaN
# 269               NaN                      NaN                 NaN
# 270               NaN                      NaN                 NaN
#
#     Customer ID(chargebee) Due Renewal Date  ... Updated Forecast Account ESM  \
# 0           gG89SwlyPrIqgt         7-Feb-25  ...           333450         NaN
# 1        AzyhPRTyX7byX3hTd        29-Apr-25  ...            45000         NaN
# 2        AzZnPeU5mGpz43CRq         5-Mar-25  ...            44200         NaN
# 3        16CV71UC6IUIT2HF2         1-Jun-25  ...            27000         NaN
# 4        16CV3LUMIkV123Hjd        26-Aug-25  ...            44000         NaN
# ..                     ...              ...  ...              ...         ...
# 266                    NaN              NaN  ...              NaN         NaN
# 267                    NaN              NaN  ...              NaN         NaN
# 268                    NaN              NaN  ...              NaN         NaN
# 269                    NaN              NaN  ...              NaN         NaN
# 270                    NaN              NaN  ...              NaN         NaN
#
#     Renewal Probabiltiy %  \
# 0                    100%
# 1                     100
# 2                     NaN
# 3                      75
# 4                     NaN
# ..                    ...
# 266                   NaN
# 267                   NaN
# 268                   NaN
# 269                   NaN
# 270                   NaN
#
#     Renewal probability of Q2 and Q3 accounts as on 9th April Unnamed: 53
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2                                                  NaN                NaN
# 3                                                  NaN                NaN
# 4                                                  NaN                NaN
# ..                                                 ...                ...
# 266                                                NaN                NaN
# 267                                                NaN                NaN
# 268                                                NaN                NaN
# 269                                                NaN                NaN
# 270                                                NaN                NaN
#
# [271 rows x 54 columns]

# %%
# c) Limit displayed rows/columns

pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 10)
print(data)
# Out:
#     Due Renewal Month Due Renewal Month Static Due Renewal Quarter  \
# 0           02|Feb'25                02|Feb'25               Qtr-1
# 1           04|Apr'25                04|Apr'25               Qtr-2
# 2           03|Mar'25                03|Mar'25               Qtr-1
# 3           06|Jun'25                06|Jun'25               Qtr-2
# 4           08|Aug'25                08|Aug'25               Qtr-3
# ..                ...                      ...                 ...
# 266               NaN                      NaN                 NaN
# 267               NaN                      NaN                 NaN
# 268               NaN                      NaN                 NaN
# 269               NaN                      NaN                 NaN
# 270               NaN                      NaN                 NaN
#
#     Customer ID(chargebee) Due Renewal Date  ... Updated Forecast Account ESM  \
# 0           gG89SwlyPrIqgt         7-Feb-25  ...           333450         NaN
# 1        AzyhPRTyX7byX3hTd        29-Apr-25  ...            45000         NaN
# 2        AzZnPeU5mGpz43CRq         5-Mar-25  ...            44200         NaN
# 3        16CV71UC6IUIT2HF2         1-Jun-25  ...            27000         NaN
# 4        16CV3LUMIkV123Hjd        26-Aug-25  ...            44000         NaN
# ..                     ...              ...  ...              ...         ...
# 266                    NaN              NaN  ...              NaN         NaN
# 267                    NaN              NaN  ...              NaN         NaN
# 268                    NaN              NaN  ...              NaN         NaN
# 269                    NaN              NaN  ...              NaN         NaN
# 270                    NaN              NaN  ...              NaN         NaN
#
#     Renewal Probabiltiy %  \
# 0                    100%
# 1                     100
# 2                     NaN
# 3                      75
# 4                     NaN
# ..                    ...
# 266                   NaN
# 267                   NaN
# 268                   NaN
# 269                   NaN
# 270                   NaN
#
#     Renewal probability of Q2 and Q3 accounts as on 9th April Unnamed: 53
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2                                                  NaN                NaN
# 3                                                  NaN                NaN
# 4                                                  NaN                NaN
# ..                                                 ...                ...
# 266                                                NaN                NaN
# 267                                                NaN                NaN
# 268                                                NaN                NaN
# 269                                                NaN                NaN
# 270                                                NaN                NaN
#
# [271 rows x 54 columns]

# %%
sample = data.sample(100)  # randomly pick 100 rows
print(sample)
# Out:
#     Due Renewal Month Due Renewal Month Static Due Renewal Quarter  \
# 37          02|Feb'25                02|Feb'25               Qtr-1
# 4           08|Aug'25                08|Aug'25               Qtr-3
# 98          06|Jun'25                06|Jun'25               Qtr-2
# 205         05|May'25                05|May'25               Qtr-2
# 105         11|Nov'25                11|Nov'25               Qtr-4
# ..                ...                      ...                 ...
# 93          02|Feb'25                02|Feb'25               Qtr-1
# 149         02|Feb'25                02|Feb'25               Qtr-1
# 120         09|Sep'25                09|Sep'25               Qtr-3
# 245               NaN                      NaN                 NaN
# 254               NaN                      NaN                 NaN
#
#     Customer ID(chargebee) Due Renewal Date  ...   Updated Forecast  \
# 37       16BQkRTVlzhpW3WXo        24-Feb-25  ...               3500
# 4        16CV3LUMIkV123Hjd        26-Aug-25  ...              44000
# 98        AzZN3gT80YodZ1At         6-Jun-25  ...  Out for Signature
# 205       16A6VqTfqXLUnYcm        31-May-25  ...                NaN
# 105      AzZcnnTXHBlBa9iHM         2-Nov-25  ...               8000
# ..                     ...              ...  ...                ...
# 93       16BVDET2qkJFQ3851         1-Feb-25  ...               4200
# 149      AzZKRtTuRqFII1duh        28-Feb-25  ...               3500
# 120     cus_Iegtvzz5n53HxD         4-Sep-25  ...               5500
# 245                    NaN              NaN  ...                NaN
# 254                    NaN              NaN  ...                NaN
#
#     Account ESM Renewal Probabiltiy %  \
# 37          NaN                  100%
# 4           NaN                   NaN
# 98          NaN                  100%
# 205         NaN                 0.00%
# 105         NaN               100.00%
# ..          ...                   ...
# 93          NaN                    25
# 149         NaN                  100%
# 120         NaN                   NaN
# 245         NaN                   NaN
# 254         NaN                   NaN
#
#     Renewal probability of Q2 and Q3 accounts as on 9th April Unnamed: 53
# 37                                                 NaN                NaN
# 4                                                  NaN                NaN
# 98                                                 NaN             3600.0
# 205                                                NaN                0.0
# 105                                                NaN             5000.0
# ..                                                 ...                ...
# 93                                                 NaN                NaN
# 149                                                NaN            14000.0
# 120                                                NaN                NaN
# 245                                                NaN                NaN
# 254                                                NaN                NaN
#
# [100 rows x 54 columns]
